# %%
#python/data analysis review

# %%
#EXAMPLE
#remember: syntax and punctuation is KEY 

#step 1: import necessary packages. usually not a need in jupyter because we have the ipykernel, but sometimes it may be necessary. 
# to check the installed packages, run the following command:
# !pip list
# !pip install pandas 
# this is better to do in terminal, but I put it here so you know to do it. apparently the python kernel doesn't come with pandas. 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Package                   Version
# ------------------------- ---------
# anyio                     4.0.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# async-lru                 2.0.4
# attrs                     23.1.0
# Babel                     2.13.1
# beautifulsoup4            4.12.2
# bleach                    6.1.0
# certifi                   2023.7.22
# cffi                      1.16.0
# charset-normalizer        3.3.2
# colorama                  0.4.6
# comm                      0.2.0
# contourpy                 1.2.0
# cycler                    0.12.1
# debugpy                   1.8.0
# decorator                 5.1.1
# defusedxml                0.7.1
# executing                 2.0.1
# fastjsonschema            2.19.0
# fonttools                 4.44.3
# fqdn                      1.5.1
# idna                      3.4
# ipykernel                 6.26.0
# ...

# %%
#step 2: import your dataset. this can happen a number of ways, use the internet/ChatGPT as a reference if you are stuck.
#this line tells python where my data frame (dataset) is in my computer. it starts in the sidebar with all of your folders (aka file explorer)
#note the double \\ rather than \
file_path = 'C:\\Users\\yaboy\\OneDrive\\dahlresearch\\practicefile_ncaa.csv'
#this opens the dataset and names it "ncaa" for future usage
ncaa = pd.read_csv(file_path)
#this allows you to see the first few rows of your data frame
print(ncaa.head())
# Out:
#    YEAR  TEAM NO     TEAM  SEED  ROUND  POWER RATING  POWER RATING RANK
# 0  2023      993  Houston     1     16          93.2                 13
# 1  2023     1011  Alabama     1     16          92.6                 16
# 2  2023      986   Kansas     1     32          89.6                 49
# 3  2023      963   Purdue     1     64          89.5                 50
# 4  2023      957    Texas     2      8          90.1                 43

# %%
ncaa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 476 entries, 0 to 475
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   YEAR               476 non-null    int64
#  1   TEAM NO            476 non-null    int64
#  2   TEAM               476 non-null    object
#  3   SEED               476 non-null    int64
#  4   ROUND              476 non-null    int64
#  5   POWER RATING       476 non-null    float64
#  6   POWER RATING RANK  476 non-null    int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 26.2+ KB
